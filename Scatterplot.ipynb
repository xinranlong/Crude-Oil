# %%
import pandas as pd

# %%
data=pd.read_csv('output/A.txt')

# %%
data
# Out:
#     week_number       std  users_holding
# 0           1.0  0.004717     584.580000
# 1           2.0  0.048265    1026.101716
# 2           3.0  0.013328     970.191176
# 3           4.0  0.017746     903.660417
# 4           5.0  0.010212     852.258333
# ..          ...       ...            ...
# 85         86.0  0.028686    1154.376634
# 86         87.0  0.007735    1172.623188
# 87         88.0  0.016566    1185.494993
# 88         89.0  0.015456    1188.832971
# 89         90.0  0.005586    1267.716667
#
# [90 rows x 3 columns]

# %%
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

# %%
plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')

# %%
plt.scatter(data.users_holding,data.std)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-b154b3772c85> in <module>
# ----> 1 plt.scatter(data.users_holding,data.std)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4442         y = np.ma.ravel(y)
#    4443         if x.size != y.size:
# -> 4444             raise ValueError("x and y must be the same size")
#    4445
#    4446         if s is None:
#
# ValueError: x and y must be the same size

# %%
import os             
all_files = os.listdir("output/")   
print(all_files)
# Out:
# ['ITB.txt', 'PPLT.txt', 'IWY.txt', 'BGH.txt', 'AROW.txt', 'AKCA.txt', 'MTNB.txt', 'HENOY.txt', 'KMB.txt', 'IWN.txt', 'NTRA.txt', 'PPLC.txt', 'VFVA.txt', 'UGE.txt', 'NSTG.txt', 'DDIV.txt', 'GOGL.txt', 'DMAC.txt', 'ECF.txt', 'ENV.txt', 'KNOP.txt', 'ZKIN.txt', 'PVH.txt', 'DVYE.txt', 'FLKR.txt', 'DCMYY.txt', 'BKK.txt', 'ARCT.txt', 'LFC.txt', 'BHP.txt', 'BIT.txt', 'ENOB.txt', 'IYE.txt', 'ISZE.txt', 'ARCC.txt', 'LEO.txt', 'SRET.txt', 'UJB.txt', 'WEYS.txt', 'MAYS.txt', 'APYX.txt', 'JMOM.txt', 'IYR.txt', 'SPIB.txt', 'FNGS.txt', 'GAL.txt', 'CHEF.txt', 'ANDA.txt', 'HEWP.txt', 'PCI.txt', 'SNCR.txt', 'ORTX.txt', 'GTIP.txt', 'LULU.txt', 'OPNT.txt', 'CTVA.txt', 'FNGD.txt', 'RYE.txt', 'DTUS.txt', 'ANDV.txt', 'PAA.txt', 'OUSM.txt', 'DALI.txt', 'ROYT.txt', 'HEWG.txt', 'BRKR.txt', 'WFC.txt', 'WEX.txt', 'SPHQ.txt', 'HYDW.txt', 'KIRK.txt', 'BSM.txt', '
t', 'CLX.txt', 'DIVY.txt', 'BMRC.txt', 'TXRH.txt', 'TMF.txt', 'RE.txt', 'MCO.txt', 'JFR.txt', 'FPE.txt', 'CNF.txt', 'AUY.txt', 'MCN.txt', 'AVB.txt', 'NILSY.txt', 'EAGG.txt', 'TLC.txt', 'VIST.txt', 'LMST.txt', 'CNSL.txt', 'AWF.txt', 'PVAC.txt', 'PACQ.txt', 'FOVL.txt', 'TMP.txt', 'MCY.txt', 'RS.txt', 'CNQ.txt', 'FSFG.txt', 'FANUY.txt', 'NYMX.txt', 'AVXL.txt', 'DKL.txt', 'PFFL.txt', 'FDEF.txt', 'SHM.txt', 'QSR.txt', 'SJR.txt', 'DIS.txt', 'MITK.txt', 'SDAG.txt', 'EFAV.txt', 'DIVO.txt', 'EQAL.txt', 'TOO.txt', 'TLT.txt', 'LTPZ.txt', 'XTH.txt', 'MOM.txt', 'SCIJ.txt', 'JJP.txt', 'DGX.txt', 'SGB.txt', 'MPWR.txt', 'SDY.txt', 'STIP.txt', 'BSVN.txt', 'SCHN.txt', 'MNI.txt', 'DELL.txt', 'OSIS.txt', 'CCA.txt', 'OVM.txt', 'FTLB.txt', 'SHYL.txt', 'CAI.txt', 'UNFI.txt', 'LVHI.txt', 'ADIL.txt', 'SGU.txt', 'HRC.txt', 'PQIN.txt', 'JJG.txt', 'JHX.txt', 'NEPT.txt', 'JPUS.txt', 'WFHY.txt', 'TMFC.txt', 'CBIO.txt', 'ASHR.txt', 'FHB.txt', 'OXLC.txt', 'BSCO.txt', 'SSG.txt', 'HOOK.txt', 'INVA.txt', 'MLPG.txt', 'CLSN.txt', 'KF.txt', 'OAS.txt', 'POWL.txt', 'SRC.txt', 'FIF.txt', 'LLESY.txt', 'SSP.txt', 'BHVN.txt', 'BOSS.txt', 'FTXG.txt', 'AMH.txt', 'HABT.txt', 'VIIZ.txt', 'TWI.txt', 'CWS.txt', 'ALL.txt', 'DRN.txt', 'SRT.txt', 'AMTX.txt', 'IEIH.txt', 'STRM.txt', 'HII.txt', 'HSPX.txt', 'CGNX.txt', 'MWK.txt', 'ABG.txt', 'MTP.txt', 'SSTK.txt', 'IBMQ.txt', 'JPMB.txt', 'FAMI.txt', 'MVO.txt', 'CBRE.txt', 'OMP.txt', 'ACC.txt', 'GE.txt', 'SCPH.txt', 'JPI.txt', 'BSMS.txt', 'FGM.txt', 'HDSN.txt', 'MPLX.txt', 'XLY.txt', 'AFIN.txt', 'MTG.txt', 'RENW.txt', 'REML.txt', 'FV.txt', 'MUC.txt', 'SDVY.t ...
